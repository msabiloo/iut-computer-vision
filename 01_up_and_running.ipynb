# %% [markdown]
# <a href="https://colab.research.google.com/github/msabiloo/iut-computer-vision/blob/main/01_up_and_running.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # نصب OpenCV در ویندوز
# برای نصب OpenCV-Python در سیستم عامل ویندوز مراحل زیر را انجام دهید:
# ## نصب آخرین نسخه از زبان برنامه‌نویسی پایتون
# * راهنمای نصب آخرین نسخه از زبان برنامه‌نویسی پایتون در [https://www.python.org/downloads/](https://www.python.org/downloads/)
# * پس از دانلود و نصب، برای اینکه مطمئن شویم به درستی نصب شده است، command prompt سیستم عامل ویندوز را باز کنید و دستور زیر را وارد کنید:
#     * `python --version`
#
# ![install-opencv-01.PNG](data:image/png;base64,...)
# ## نصب پکیج Numpy با استفاده از pip
# * `pip install numpy`
#
# ![image.png](data:image/png;base64,...)
# ## نصب پکیج Matplotlib با استفاده از pip
# * `pip install matplotlib`
#
# ![image.png](data:image/png;base64,...)
# ## نصب آخرین نسخه از opencv-python
# * `pip install opencv-python`
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # اولین برنامه با استفاده از OpenCV

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import sys
img = cv.imread("/content/OpenCV_logo_black-2.png")
if img is None:
 sys.exit("Could not read the image.")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=328x433>
